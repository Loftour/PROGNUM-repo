# %%
import numpy as np
x=np.random.randint(1,3)
R=1
P=2
S=3
n=input("rock, paper or scissors?")
if n==x:
    print("draw")
elif n==1 and x==3:
    print("win")
elif n==2 and x==1:
    print("win")
elif n==3 and x==2:
    print("win")
elif n==1 and x==2:
    print("loss")
elif n==2 and x==3:
    print("loss")
else:
    print("loss")
print(x)
