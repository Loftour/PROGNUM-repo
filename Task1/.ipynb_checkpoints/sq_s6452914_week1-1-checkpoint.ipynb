# %% [markdown]
# Answers for Week 1
#
# * Name: Michael Lavik
# * Username: mclavik
# * Student s-number: S-6452914
# * Group (AS1, etc.): AS4

# %%
x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %%
x = 6
print(x)
x*=5
print(x)
x*=4
print(x)
x*=3
print(x)
x*=2
print(x)
# Out:
# 6
# 30
# 120
# 360
# 720

# %%
e=1.6*10**-19
print(e)
f=2.42*10**28
print(f)
c=3*10**8
print(c)
h=6.63*10**-34
print(h)

lam=c/f
print(lam)

E=(h*c)/lam
print(E)

ev=E/e
print(ev)
# Out:
# 1.6000000000000002e-19
# 2.4199999999999996e+28
# 300000000
# 6.629999999999999e-34
# 1.2396694214876036e-20
# 1.6044599999999995e-05
# 100278749999999.97

# %%
from scipy.constants import G
M1=5.9772*10**24
M2=7.342*10**22
r=385.0006*10**6
F=(G*M1*M2)/r**2
print(F)
# Out:
# 1.9760370306527268e+20
